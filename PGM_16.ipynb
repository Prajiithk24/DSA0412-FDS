# %%
import pandas as pd
from collections import Counter
import re

data = {
    "reviews": [
        "This product is very good and useful",
        "The quality of the product is excellent",
        "Very bad experience with this product",
        "The product quality is good and price is reasonable",
        "Excellent product and very good performance"
    ]
}

# %%
df = pd.DataFrame(data)

all_text = " ".join(df["reviews"]).lower()
words = re.findall(r'\b\w+\b', all_text)
word_freq = Counter(words)

# %%
print(word_freq)
# Out:
# Counter({'product': 5, 'is': 4, 'very': 3, 'good': 3, 'and': 3, 'the': 3, 'this': 2, 'quality': 2, 'excellent': 2, 'useful': 1, 'of': 1, 'bad': 1, 'experience': 1, 'with': 1, 'price': 1, 'reasonable': 1, 'performance': 1})
