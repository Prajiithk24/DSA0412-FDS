# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Customer_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Age': [25, 30, 22, 30, 25, 40, 22, 30],
    'Purchase_Amount': [500, 1200, 300, 800, 650, 1500, 400, 900]
}

# %%
df = pd.DataFrame(data)
age_frequency = df['Age'].value_counts().sort_index()

# %%
print("Frequency Distribution of Customer Ages:")
print(age_frequency)
# Out:
# Frequency Distribution of Customer Ages:
# Age
# 22    2
# 25    2
# 30    3
# 40    1
# Name: count, dtype: int64

# %%
plt.bar(age_frequency.index, age_frequency.values)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Customer Ages')
plt.show()
